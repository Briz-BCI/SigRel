# %%
from keras.datasets import mnist

# %%
(X_train, y_train), (X_val, y_val)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_val.shape
# Out:
# (10000, 28, 28)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.callbacks import Callback

# %%
y_val.shape
# Out:
# (10000,)

# %%
X_train=X_train.astype('float32')/255
X_val=X_val.astype('float32')/255

# %%
n_classes=10
y_train=to_categorical(y_train, n_classes)
y_val=to_categorical(y_val, n_classes)

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train=np.reshape(X_train,(60000, 784))
X_val=np.reshape(X_val, (10000,784))

# %%
model_sigmoid=Sequential()
model_sigmoid.add(Dense(600, input_dim=784, activation='sigmoid'))
model_sigmoid.add(Dense(300,activation='sigmoid'))
model_sigmoid.add(Dense(100,activation='sigmoid'))
model_sigmoid.add(Dense(10,activation='softmax'))

# %%
model_sigmoid.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
model_sigmoid.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 600)               471000
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               180300
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 682,410
# Trainable params: 682,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
n_epochs=10
batch_size=256
validation_split=0.2
model_sigmoid.fit(X_train, y_train, epochs=n_epochs, batch_size=batch_size, validation_split=validation_split, verbose=2)
# Out:
# Epoch 1/10
# 188/188 - 5s - loss: 2.3156 - accuracy: 0.1105 - val_loss: 2.2998 - val_accuracy: 0.1060
# Epoch 2/10
# 188/188 - 4s - loss: 2.2972 - accuracy: 0.1140 - val_loss: 2.2967 - val_accuracy: 0.1060
# Epoch 3/10
# 188/188 - 4s - loss: 2.2945 - accuracy: 0.1140 - val_loss: 2.2937 - val_accuracy: 0.1060
# Epoch 4/10
# 188/188 - 4s - loss: 2.2918 - accuracy: 0.1174 - val_loss: 2.2909 - val_accuracy: 0.1060
# Epoch 5/10
# 188/188 - 4s - loss: 2.2889 - accuracy: 0.1140 - val_loss: 2.2875 - val_accuracy: 0.1060
# Epoch 6/10
# 188/188 - 4s - loss: 2.2859 - accuracy: 0.1145 - val_loss: 2.2847 - val_accuracy: 0.1072
# Epoch 7/10
# 188/188 - 4s - loss: 2.2827 - accuracy: 0.1169 - val_loss: 2.2813 - val_accuracy: 0.1157
# Epoch 8/10
# 188/188 - 4s - loss: 2.2795 - accuracy: 0.1184 - val_loss: 2.2782 - val_accuracy: 0.1060
# Epoch 9/10
# 188/188 - 4s - loss: 2.2760 - accuracy: 0.1221 - val_loss: 2.2747 - val_accuracy: 0.1060
# Epoch 10/10
# 188/188 - 4s - loss: 2.2723 - accuracy: 0.1257 - val_loss: 2.2704 - val_accuracy: 0.1343

# %%
model_relu=Sequential()
model_relu.add(Dense(600, input_dim=784, activation='relu'))
model_relu.add(Dense(300,activation='relu'))
model_relu.add(Dense(100,activation='relu'))
model_relu.add(Dense(10,activation='softmax'))

# %%
model_relu.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
n_epochs=10
batch_size=256
validation_split=0.2
model_relu.fit(X_train, y_train, epochs=n_epochs, batch_size=batch_size, validation_split=validation_split, verbose=2)
# Out:
# Epoch 1/10
# 188/188 - 5s - loss: 1.7473 - accuracy: 0.5646 - val_loss: 1.0688 - val_accuracy: 0.7986
# Epoch 2/10
# 188/188 - 4s - loss: 0.7740 - accuracy: 0.8306 - val_loss: 0.5459 - val_accuracy: 0.8701
# Epoch 3/10
# 188/188 - 4s - loss: 0.5018 - accuracy: 0.8735 - val_loss: 0.4159 - val_accuracy: 0.8911
# Epoch 4/10
# 188/188 - 4s - loss: 0.4112 - accuracy: 0.8904 - val_loss: 0.3599 - val_accuracy: 0.9007
# Epoch 5/10
# 188/188 - 4s - loss: 0.3650 - accuracy: 0.9002 - val_loss: 0.3299 - val_accuracy: 0.9078
# Epoch 6/10
# 188/188 - 4s - loss: 0.3358 - accuracy: 0.9065 - val_loss: 0.3090 - val_accuracy: 0.9116
# Epoch 7/10
# 188/188 - 4s - loss: 0.3142 - accuracy: 0.9116 - val_loss: 0.2919 - val_accuracy: 0.9170
# Epoch 8/10
# 188/188 - 4s - loss: 0.2973 - accuracy: 0.9160 - val_loss: 0.2769 - val_accuracy: 0.9218
# Epoch 9/10
# 188/188 - 4s - loss: 0.2830 - accuracy: 0.9197 - val_loss: 0.2665 - val_accuracy: 0.9249
# Epoch 10/10
# 188/188 - 4s - loss: 0.2712 - accuracy: 0.9226 - val_loss: 0.2550 - val_accuracy: 0.9273
